# %%
import scanpy as sc
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import wasserstein_distance
import seaborn as sns
from tqdm import tqdm

from rpy2.robjects.packages import importr

from scrna.cluster.main import compute_dimensionality_reductions
from optimalSeparation import searchOptimal, dataLoading, visualization

# %%
# adataFull = sc.read_h5ad('../../data/h5ads/jostner-processed.h5ad')
# adata = adataFull[adataFull.obs['sample'] == 'mdamb231']
data_mat = adata.copy().T.to_df()

# %%
data_mat
# Out:
#              AAACCCAAGTGAGGTC-2  AAACCCACAATGGGTG-2  AAACCCACAGGCACAA-2  \
# MIR1302-2HG                 0.0                 0.0                 0.0
# FAM138A                     0.0                 0.0                 0.0
# OR4F5                       0.0                 0.0                 0.0
# AL627309.1                  0.0                 0.0                 0.0
# AL627309.3                  0.0                 0.0                 0.0
# ...                         ...                 ...                 ...
# AC141272.1                  0.0                 0.0                 0.0
# AC023491.2                  0.0                 0.0                 0.0
# AC007325.1                  0.0                 0.0                 0.0
# AC007325.4                  0.0                 0.0                 0.0
# AC007325.2                  0.0                 0.0                 0.0
#
#              AAACCCAGTAGGCAAC-2  AAACGAAAGAGGTTAT-2  AAACGAAAGCGCTGCT-2  \
# MIR1302-2HG                 0.0                 0.0                 0.0
# FAM138A                     0.0                 0.0                 0.0
# OR4F5                       0.0                 0.0                 0.0
# AL627309.1                  0.0                 0.0                 0.0
# AL627309.3                  0.0                 0.0                 0.0
# ...                         ...                 ...                 ...
# AC141272.1                  0.0                 0.0                 0.0
# AC023491.2                  0.0                 0.0                 0.0
# AC007325.1                  0.0                 0.0                 0.0
# AC007325.4                  0.0                 0.0                 0.0
# AC007325.2                  0.0                 0.0                 0.0
#
#              AAACGCTAGGTCGTCC-2  AAAGAACAGAGTGAAG-2  AAAGAACAGCAAACAT-2  \
# MIR1302-2HG                 0.0                 0.0                 0.0
# FAM138A                     0.0                 0.0                 0.0
# OR4F5                       0.0                 0.0                 0.0
# AL627309.1                  0.0                 0.0                 0.0
# AL627309.3                  0.0                 0.0                 0.0
# ...                         ...                 ...                 ...
# AC141272.1                  0.0                 0.0                 0.0
# AC023491.2                  0.0                 0.0                 0.0
# AC007325.1                  0.0                 0.0                 0.0
# AC007325.4                  0.0                 0.0                 0.0
# AC007325.2                  0.0                 0.0                 0.0
#
#              AAAGAACAGCGTGAGT-2  ...  TTTGATCGTGTACATC-2  TTTGATCTCAGATTGC-2  \
# MIR1302-2HG                 0.0  ...                 0.0                 0.0
# FAM138A                     0.0  ...                 0.0                 0.0
# OR4F5                       0.0  ...                 0.0                 0.0
# AL627309.1                  0.0  ...                 0.0                 0.0
# AL627309.3                  0.0  ...                 0.0                 0.0
# ...                         ...  ...                 ...                 ...
# AC141272.1                  0.0  ...                 0.0                 0.0
# AC023491.2                  0.0  ...                 0.0                 0.0
# AC007325.1                  0.0  ...                 0.0                 0.0
# AC007325.4                  0.0  ...                 0.0                 0.0
# AC007325.2                  0.0  ...                 0.0                 0.0
#
#              TTTGGAGGTCTTCCGT-2  TTTGGAGTCGACATTG-2  TTTGGAGTCGCCGAGT-2  \
# MIR1302-2HG                 0.0                 0.0                 0.0
# FAM138A                     0.0                 0.0                 0.0
# OR4F5                       0.0                 0.0                 0.0
# AL627309.1                  0.0                 0.0                 0.0
# AL627309.3                  0.0                 0.0                 0.0
# ...                         ...                 ...                 ...
# AC141272.1                  0.0                 0.0                 0.0
# AC023491.2                  0.0                 0.0                 0.0
# AC007325.1                  0.0                 0.0                 0.0
# AC007325.4                  0.0                 0.0                 0.0
# AC007325.2                  0.0                 0.0                 0.0
#
#              TTTGGAGTCTGGGCCA-2  TTTGGTTTCACTCACC-2  TTTGTTGCATATGCGT-2  \
# MIR1302-2HG                 0.0                 0.0                 0.0
# FAM138A                     0.0                 0.0                 0.0
# OR4F5                       0.0                 0.0                 0.0
# AL627309.1                  0.0                 0.0                 0.0
# AL627309.3                  0.0                 0.0                 0.0
# ...                         ...                 ...                 ...
# AC141272.1                  0.0                 0.0                 0.0
# AC023491.2                  0.0                 0.0                 0.0
# AC007325.1                  0.0                 0.0                 0.0
# AC007325.4                  0.0                 0.0                 0.0
# AC007325.2                  0.0                 0.0                 0.0
#
#              TTTGTTGGTAAGTTGA-2  TTTGTTGTCCCTTGTG-2
# MIR1302-2HG                 0.0                 0.0
# FAM138A                     0.0                 0.0
# OR4F5                       0.0                 0.0
# AL627309.1                  0.0                 0.0
# AL627309.3                  0.0                 0.0
# ...                         ...                 ...
# AC141272.1                  0.0                 0.0
# AC023491.2                  0.0                 0.0
# AC007325.1                  0.0                 0.0
# AC007325.4                  0.0                 0.0
# AC007325.2                  0.0                 0.0
#
# [36601 rows x 2922 columns]

# %%
import anndata2ri
import logging

import rpy2.rinterface_lib.callbacks as rcb
import rpy2.robjects as ro
from rpy2.robjects.packages import importr

rcb.logger.setLevel(logging.ERROR)
ro.pandas2ri.activate()
anndata2ri.activate()
# Out:
# /tmp/ipykernel_2445207/2573892284.py:10: DeprecationWarning: The global conversion available with activate() is deprecated and will be removed in the next major release. Use a local converter.
#   anndata2ri.activate()

# %%
importr('Seurat')

importAdataToSeurat_r = ro.r(
    """
    function(data_mat){
        seu = CreateSeuratObject(counts = data_mat)

        seu
    }
    
    
    
    """
)

importAdataToSeurat = ro.functions.wrap_r_function(importAdataToSeurat_r, 'importAdataToSeurat')

# %%
out = runScDbl(
    data_mat
)
